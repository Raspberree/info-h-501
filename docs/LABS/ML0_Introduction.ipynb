# %% [markdown]
# # Machine Learning 0 - Introduction
#
# In this lab, we will introduce the classification problem that we will be working on for the last three labs. The objectives of the lab are:
#
# * Examine the dataset and prepare the basic pipeline that will be used in the next lab.
# * Make sure that we use a correct methodology for comparing the algorithms
# * Get used to working with the [scikit-learn](https://scikit-learn.org/stable/) library.
#
# ## Important note
#
# For the machine learning labs, **each student must write a report** (one report for all labs together) which will be used during the oral exam. This report should highlight the different methods used during the labs, but also how you validated each method and compared their results.

# %% [markdown]
# ## Introduction to the dataset
#
# The [CIFAR-10](https://www.cs.toronto.edu/~kriz/cifar.html) dataset has been collected by Alex Krizhevsky, Vinod Nair, and Geoffrey Hinton. It consists of 60.000 32x32 colour images, split in 10 classes: 'airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'.
#
# *Reference: Learning Multiple Layers of Features from Tiny Images, Alex Krizhevsky, 2009.* PDF available at https://www.cs.toronto.edu/~kriz/learning-features-2009-TR.pdf
#
# For the purpose of the INFO-H-501 laboratories, we will use a subset of those images by only taking 3 different classes: 'airplane', 'bird' and 'horse'.
#
# [Click here to download](https://my.pcloud.com/publink/show?code=XZJUCPkZqiVxqtn8CXRB7D78YKt88RJvzWyk) the modified dataset. Extract the ZIP file and put the CIFAR10 folder in the same directory as the notebook.
#
# The images are 32x32 8-bit **RGB**, and from these we extracted **Histogram of Gradient** vectors (16 orientations x 16 blocks = 256 values in HoG vector).
#
# The following code pre-loads all of this data (make sure that you have the [lab_tools.py](https://github.com/odebeir/info-h-500-501/blob/master/LABS1/lab_tools.py) file in the same directory as the notebook, if you didn't clone the repository):

# %%
from lab_tools import CIFAR10, get_hog_image
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import cross_val_score

# %%
# displays the first 64 training images, each as a32x32px RGB image
dataset = CIFAR10('CIFAR10/')

# %matplotlib inline

plt.figure(figsize=(10,12))
for i in range(64):
    plt.subplot(8,8,i+1)
    plt.imshow(dataset.train['images'][i].reshape((32,32,3)), interpolation='none')
    plt.title(dataset.labels[dataset.train['labels'][i]])
    plt.axis('off')
plt.show()
# Out:
# Pre-loading training data
# Pre-loading test data

# %% [markdown]
# We can also have a look at some HoG images:

# %%
# HoG representation of the first 16 images in the training dataset
plt.figure(figsize=(8,8))
for i in range(16):
    plt.subplot(4,4,i+1)
    hog = dataset.train['hog'][i].reshape((4,4,16))
    plt.imshow(get_hog_image(hog, 128), interpolation='none')
    plt.title(dataset.labels[dataset.train['labels'][i]])
    plt.axis('off')
plt.show()

# %% [markdown]
# Note that this is an "image" representation of the HoG, but that the actual data that we will be working on is a size 256 vector for each image. Our **feature space** has therefore 256 dimensions.

# %% [markdown]
# Personal notes :
#
# In other words, The classifier does not use this 4x4x16 visualization directly.
# The actual input to the classifier is a flat 1D vector of 256 numerical features.
#
#
# What is HoG ?
# HoG describes an image by summarizing the **orientation** and **strength** of its **local** edges. (local: HoG describes where edges are locally present in the image. Here we have 4x4=16 local positions where edges can be detected).
# This is useful because object shape is often more informative than raw colour values.
#
# In this practical, each image is split into a grid of **4 × 4** local spatial blocks.
# For each local block, gradients are computed in **16** orientations.
#
# Therefore, the total flattened 1D feature vector size is : 4 × 4 blocks × 16 orientations = 256 HoG features / image (or 256 dimensions / image)
#
#
# Perso : Why use HoG ?
# Using raw pixels would mean representing each RGB image as:
# 32 × 32 × 3 = 3072 raw pixel values
# That is much higher-dimensional than the 256-dimensional HoG representation.
# For classical machine learning methods, such as k-nearest neighbours, decision trees, SVMs, or linear classifiers, it is often better to work with meaningful extracted features rather than raw pixel values. (Bc working with handcrafted features is more efficient and has better performance ?)

# %% [markdown]
# ## Exploring the dataset
#
# The *dataset* object gives you access to different attributes:
#
# * *dataset.path* contains the path to the CIFAR10 folder.
# * *dataset.labels* contains the name of the three classes
# * *dataset.train* and *dataset.test* are dictionaries containing three numpy arrays each:
#     * *images* contains the RGB images
#     * *hog* contains the HoG vectors
#     * *labels* contains the label for each image

# %%
print(dataset.path)
print(dataset.labels)
print(dataset.train.keys())
print(dataset.train['hog'].shape)
# Out:
# CIFAR10/
# ['Airplane', 'Bird', 'Horse']
# dict_keys(['images', 'hog', 'labels'])
# (15000, 256)

# %% [markdown]
# ### Quick questions:
#
# The dataset has already been split into a training set (dataset.train) and a test set (dataset.test).
#
# * How many images are in the training set ?
# * How many images are in the test set ?
# * What is the class distribution of the dataset ?

# %%
# -- Your code here -- #

# How many images are in the training set ?
print("Training set:", len(dataset.train["images"])) # Option 2 : print(len(dataset.train["hog"]))


# How many images are in the test set ?
print("Test set:", len(dataset.test["images"]))

# What is the class distribution of the dataset ?
labs = {0 : "Airplane",
        1 : "Bird",
        2 : "Horse"}

print("\n=== Training Set ===")
dist = np.unique_counts(dataset.train["labels"])
for a, b in zip(dist.values, dist.counts):
    print(labs.get(a), b)


print("\n=== Test Set ===")
dist = np.unique_counts(dataset.test["labels"])
for a, b in zip(dist.values, dist.counts):
    print(labs.get(a), b)
# Out:
# Training set: 15000
# Test set: 3000
#
# === Training Set ===
# Airplane 5000
# Bird 5000
# Horse 5000
#
# === Test Set ===
# Airplane 1000
# Bird 1000
# Horse 1000

# %% [markdown]
# Personal notes :
# Dataset classes are balalanced, which is important for accuracy metrics interpretation
#
# For example, if 95% of samples belong to one class, a useless classifier that always predicts that class will already reach 95% accuracy.

# %% [markdown]
# ### Descriptive data analysis
#
# Look at the HoG data from the training set. What are the characteristics of the dataset ? Do you think that some pre-processing may be required to help with the different algorithms ?

# %%
# -- Your code here -- #
import pandas as pd
X_train = dataset.train['hog']
y_train = dataset.train['labels']

columns=[i for i in range(256)] # 256 feature columns
df = pd.DataFrame(columns=columns, data=X_train)
df.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.006399  0.002071  0.001341  0.000838  0.000545  0.000713  0.001437
# 1  0.010937  0.004844  0.000789  0.000942  0.000760  0.001127  0.002262
# 2  0.008959  0.001857  0.000000  0.001131  0.000588  0.002255  0.003634
# 3  0.000194  0.002840  0.000048  0.000000  0.000020  0.000588  0.000367
# 4  0.000733  0.001007  0.000000  0.000041  0.000206  0.001347  0.000297
#
#         7         8         9    ...       246       247       248       249  \
# 0  0.000000  0.008710  0.009330  ...  0.006237  0.001140  0.008482  0.005128
# 1  0.001568  0.010407  0.001197  ...  0.004330  0.002514  0.005499  0.001196
# 2  0.007268  0.009895  0.004873  ...  0.000000  0.001580  0.001449  0.000000
# 3  0.001010  0.001543  0.000243  ...  0.003664  0.005923  0.003862  0.003463
# 4  0.000080  0.000373  0.000000  ...  0.000692  0.014606  0.022854  0.002212
#
#         250       251       252       253       254       255
# ...

# %%
X_test = dataset.test['hog']
y_test = dataset.test['labels']

X_test.shape
# Out:
# (3000, 256)

# %%
plt.figure(figsize=(5,5))
plt.hist(x=X_train.flatten(), bins=100)
plt.title("Histogram of HoG features values across all training images")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print("Shape:", X_train.shape)
print("Min:", X_train.min())
print("Max:", X_train.max())
print("Mean:", X_train.mean())
print("Std:", X_train.std())
print("Median:", np.median(X_train))
# Out:
# Shape: (15000, 256)
# Min: 0.0
# Max: 0.2251452001705904
# Mean: 0.003906249999884476
# Std: 0.005722073863398178
# Median: 0.002034900958491955

# %% [markdown]
# ## Introduction to scikit-learn
#
# [Scikit-learn](https://scikit-learn.org/stable/) is a very well documented machine learning library in Python. It contains many algorithms for [classification](https://scikit-learn.org/stable/supervised_learning.html#supervised-learning), and makes the whole process of building a machine learning pipeline relatively straightforward. There are many examples in the documentation, as well as relatively complete theoretical explanations, so I really encourage you to take the time to read it if some things are not clear.
#
# Let's make a very simple example. We are going to use the [Ridge Classifier](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.RidgeClassifier.html#sklearn.linear_model.RidgeClassifier), which is a very basic linear model.

# %%
from sklearn.linear_model import RidgeClassifier

# %% [markdown]
# To use a classifier with scikit-image, we generally have three steps:
#
# * Create an instance of the class of the classifier (here: RidgeClassifier). The constructor will generally contain many arguments that can be modified, and that are explained in the documentation. There will also generally be default values for all of them, so in this simple example we will just use those:

# %%
clf = RidgeClassifier()

# %% [markdown]
# * Use the *fit* method with, as arguments, the training data (in our case, the HoG vectors) and the corresponding labels. This will start the main training algorithm, trying to fit the parameters of the classifier with the training data:

# %%
clf.fit(dataset.train['hog'], dataset.train['labels'])
# Out:
# RidgeClassifier()

# %% [markdown]
# * Use the *predict* method to get the prediction of the classifier on the data given as argument. In this case, we get the predictions on the data that was just used for training. **What kind of performance will that give us?**

# %%
pred = clf.predict(dataset.train['hog']) # The .predict method applies the trained model to input feature vectors and returns predicted class labels
print(pred.shape)
# Out:
# (15000,)

# %% [markdown]
# We can then evaluate those predictions. Scikit-learn provides many different [metrics](https://scikit-learn.org/stable/modules/model_evaluation.html) for evaluating the performances of a classifier. The most simple of those is the accuracy, which is simply the number of correct predictions divided by the total number of predictions:

# %%
from sklearn.metrics import accuracy_score

score = accuracy_score(dataset.train['labels'], pred) # compare ground-truth labels and predicted labels
print("Accuracy =", score)

# Note that it's fairly easy to compute that score "by hand":
T = (pred==dataset.train['labels']).sum()
print(T, "/", len(pred), "=", T/len(pred))
# Out:
# Accuracy = 0.06773333333333334
# 1016 / 15000 = 0.06773333333333334

# %% [markdown]
# In a multiclass problem, it's often also very useful to look at the [confusion matrix](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html#sklearn.metrics.confusion_matrix), which gives us more information on which classes are often mistaken for each other:

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(dataset.train['labels'], pred)
print(cm)
# Out:
# [[ 514 1864 2622]
#  [2860  321 1819]
#  [3437 1382  181]]

# %%
print("Descriptive CM")
plt.figure()
from sklearn.metrics import ConfusionMatrixDisplay
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues")
plt.title("Confusion Matrix performance of model on same training data")
plt.show()
# Out:
# Descriptive CM

# %% [markdown]
# Note that the rows represent the **true labels** and the columns the **predicted labels**. So this mean that, in this case, out of the 5000 images of class 0 ("Airplane"), 3812 were correctly classified, 740 were classified as "Bird" and 448 as "Horse").

# %% [markdown]
# Personal note:
#
# Note that accuracy and confusion matrices are DESCRIPTIVE PERFORMANCE metrics (meaning that the performance is measured on the same data used for training). It measures how well the model can describe **known** data.
#
# Au contraire, PREDICTIVE PERFORMANCE is the performance measured on data that were not used for fitting the model. Predictive performance a better estimate of how the model behaves on **unseen** data. Predictive performance is also known as validation preformance.
#
# High descriptive performance coupled with poor predictive performance is a sign of **overfitting** (the model learns details specific to the training set (noise) instead of general patterns that transfer to new examples).

# %% [markdown]
# ### Quick question
#
# * Modify the code to estimate the **predictive** performance of the algorithm (without using the test set).

# %%
# -- Your code here -- #

# ============ Simple Validation Split ==========

# ------------Split of Training Set into training data and validation data--------------
print("===Row Selection===")
p_val = 0.1 # not a p-value ! Pour définir qu'on va garder 10% du training set pour la cross-validation
n_val = int(p_val*len(dataset.train["hog"])) # 10% * #data  = # rows to xclude
print(n_val, "rows excluded (Validation)")

# Select 90% of training data for training purpose
train_X = dataset.train["hog"][:-n_val]
train_Y = dataset.train["labels"][:-n_val]

# Select 10 last % of training data for cross-validation purpose
val_X = dataset.train["hog"][-n_val:]
val_Y = dataset.train["labels"][-n_val:]


print(f"""90% Training HoG : {train_X.shape} used for training
90% Training Labels : {train_Y.shape} used for training
10% Training HoG : {val_X.shape} used for Valdiation
10% Training Labels : {val_Y.shape} used for Validation""")


#--------------- Ridge Classifier --------------
print("\n===Ridge Classifier===")
# create Rdige Classifier with given hyperparameters
clf = RidgeClassifier(alpha=0.1)

# Fit model to training data (optimize parameters)
clf.fit(train_X, train_Y)

# Predictive fit : make predictions for left-out (validation) data 
# goal : test de la capacité de généralisation du modèle sur nouvelles données (et donc aussi voir si pas d'overfit) VS descriptive perofrmance
pred = clf.predict(val_X)

# Descriptive fit (same as before) for further comparison
# goal : test de la capacité de base du modèle à correctement fit les données sur lesquelles le modèle a été entraîné)
pred_descr = clf.predict(train_X)


# --------------- Compute predictive & descriptive performance ---------------
# Descriptive performance : checks underfitting
score = accuracy_score(train_Y, pred_descr)
print(f"Descriptive performance : {score:.3f}")

# Predictive performance : checks overfitting (compared to descriptive)
score = accuracy_score(val_Y, pred)
print(f"Predictive performance: {score:.3f}")
# Out:
# ===Row Selection===
# 1500 rows excluded (Validation)
# 90% Training HoG : (13500, 256) used for training
# 90% Training Labels : (13500,) used for training
# 10% Training HoG : (1500, 256) used for Valdiation
# 10% Training Labels : (1500,) used for Validation
#
# ===Ridge Classifier===
# Descriptive performance : 0.060
# Predictive performance: 0.071

# %%
# ---------------- Predictive CM --------------
cm_pred = confusion_matrix(val_Y, pred)

# Plotting
print("Predictive CM")
plt.figure()
disp = ConfusionMatrixDisplay(confusion_matrix=cm_pred)
disp.plot(cmap="Blues")
plt.title("Confusion Matrix performance of model on unseen validation data")
plt.show()
# Out:
# Predictive CM

# %%
print(np.unique_counts(train_Y))
print(np.unique_counts(val_Y))
# Out:
# UniqueCountsResult(values=array([0, 1, 2], dtype=uint8), counts=array([4488, 4510, 4502]))
# UniqueCountsResult(values=array([0, 1, 2], dtype=uint8), counts=array([512, 490, 498]))

# %% [markdown]
# ## How can we find the "best" algorithm?
#
# What we have shown above served to illustrate how scikit-learn classifiers work, but we now have to build a valid machine learning pipeline to compare the different algorithms that we will use in the next labs.
#
# As we have said earlier, we have already split the dataset into a "training" and a "test" set. It is clear that the final evaluation should take place on the test set.
#
# But in addition to comparing the algorithms between each other, we also have to find the best "hyper-parameters" for each algorithm. For example, in our RidgeClassifier example, there is a regularization parameters, *alpha*, which by default was set to 1.0. Can we improve the performance of the algorithm by modifying this parameter ?
#
# ### Side-note: parameter vs hyper-parameter
#
# In general, when talking about machine learning models, **parameters** are what the algorithm learns with the data (if we are for instance learning a linear regression y = ax+b, the "parameters" would be a and b), while **hyper-parameters** are modifiers to the model or to the pipeline (for instance, if we are generalizing to a polynomial regression, the degree of the polynome would be an hyper-parameter).
#
# ### Cross-validation
#
# The most common way of finding the best hyper-parameters of a classifier is to use [cross-validation](https://scikit-learn.org/stable/modules/cross_validation.html).
#
# * Using the [cross_val_score](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html#sklearn.model_selection.cross_val_score) method from scikit-learn, find the best *alpha* hyper-parameter for the RidgeClassifier:

# %% [markdown]
# Personal note :
# What is a Ridge Classifier ?
# RidgeClassifier is a linear classifier that combines input features using learned linear weights.
# For each class, the model learns how much each feature contributes to the decision.
#
# What is alpha ?
# RidgeClassifier includes a regularization hyperparameter called alpha.
#
# What is a regularization parameter ?
# Regularization is a RidgeClassifier hyperparameter that penalizes overly large model weights.
# The goal is to reduce overfitting by discouraging the model from relying too strongly on very specific feature patterns.
#
# How does alpha affect the learning ?
# - too small alpha -> Weak regularization ->  model can fit training data more freely but higher risk of overfitting.
# - too large alpha -> strong regularization -> weights are forced toward zero and model is more constrained, but harder for model to make any prediction = risk of underfitting
# - Alpha shoud have a compromised value minimizing underfitting and overfitting (cf over/underfitting curve)

# %%
# -- Your code here -- #
best_score = 0
best_score_std= 0
best_alpha = 0

all_scores = [] # used later for plotting

als = [0.001, 0.01, 0.1, 1, 10, 100, 1000]
for al in als:
    clf2 = RidgeClassifier(alpha=al)
    scores = cross_val_score(estimator=clf2, X=dataset.train["hog"], y=dataset.train["labels"], cv=5)
    print(al, scores)
    all_scores.append(scores) # stores for later plotting
    if scores.mean() >= best_score:
        best_score = scores.mean()
        best_score_std = scores.std()
        best_alpha = al

print(f"\nBest alpha hyperparam value = {best_alpha}, with a {best_score:0.5f} accuracy and a standard deviation of +/- {best_score_std:0.5f}")
# Out:
# 0.001 [0.06266667 0.06866667 0.07333333 0.061      0.071     ]
# 0.01 [0.063      0.06766667 0.07266667 0.05966667 0.07066667]
# 0.1 [0.064      0.06766667 0.06966667 0.058      0.06933333]
# 1 [0.073      0.07233333 0.07266667 0.067      0.071     ]
# 10 [0.087      0.08766667 0.09166667 0.083      0.08666667]
# 100 [0.093      0.097      0.09833333 0.08866667 0.09466667]
# 1000 [0.095      0.09766667 0.1        0.08866667 0.095     ]
#
# Best alpha hyperparam value = 1000, with a 0.09527 accuracy and a standard deviation of +/- 0.00379

# %%
print(np.asarray(all_scores).shape)
cv_means = np.mean(a=np.asarray(all_scores), axis=1)

plt.figure()
plt.plot(als, cv_means)
plt.title(f"Predictive Accuracy, Cross-Validation (k=5, n_alphas={len(als)})")
plt.xlabel("Alpha")
plt.ylabel("Accuracy Score")
plt.show()
# Out:
# (7, 5)

# %% [markdown]
# Personal Note :
# Wy use cross-validatio now ?
#
# Before, we used a **Simple/Naive Validation Split** to estimate predictve performance.
#
# We simply split the original training set into a smaller training subset and a validation subset.
#
# However this raises 2 problems :
# - by using a simple arbitrary index spit, we are not sure that the classes remain balanced in the smaller training subset nor in the validation subset. Especially if the original dataset was sorted in any way.
# - A single validation split to estimate predictive performance for a given hyperparameter can be misleading. This is because the validation score would depend on which examples happen to be placed in this unique validation set. But if the validation subset is slightly easier or harder than average, the score may be misleading as it will be more sensible to the only sample drawn than if the validation is repeated multiple times for each hyperparmeter value, each time with a new random sample.
#
#
# Solution :
# - Use a **stratification** method to ensure that the class distribution is preserved in both subsets (training and validation subsets) aka classes remain balanced in subsets.
# - use **Cross-Validation** to repeat the train/validation subset split and compute each predictive performance score multiple times for each hyperparameter value.
#     - The default method used is the **standard k-fold cross-validation**
#
# The solution that combines these two elements is the **stratified k-fold cross-validation**

# %% [markdown]
# ### Comparing algorithms
#
# Once you have found the best hyper-parameters for an algorithm, you can re-train the classifier on the whole training set, and finally use the test set to get a "final performance".
#
# * How can you then decide which of the classifiers is best ?
# * How can you decide if the different between two classifiers is significant ?
#
# Try to compare the best RidgeClassifier with the original. Is it significantly better?

# %% [markdown]
# Q1 : How can you then decide which of the classifiers is best ?
# We can first try to (naively) compare the final predictive accuracy of each model on the final test set

# %%
# -- Your code here -- #

# ---------- Retrain classifier on the whole training set  --------
# using default hyperparameter
clf_original = RidgeClassifier(alpha=1.0)
clf_original.fit(X=X_train,y=y_train)

# using best hyperparameter alpha
clf_best = RidgeClassifier(alpha=best_alpha)
clf_best.fit(X=X_train,y=y_train)


# ---------- Compare prediction performance to original hyperparameter  --------------
# Default hyperparameter
pred_original_test = clf_original.predict(X_test)

# Best hyperparameter
pred_best_test = clf_best.predict(X_test)


# ------------- Compute accuracy origianl vs best ----------------
acc_original = accuracy_score(y_true=y_test, y_pred=pred_original_test)
acc_best = accuracy_score(y_true=y_test, y_pred=pred_best_test)

print(f"Original alpha : {acc_original:.4f}")
print(f"Best alpha     : {acc_best:.4f}")
# Out:
# Original alpha : 0.0660
# Best alpha     : 0.0993

# %%
# --------- BONUS : Visualization of CM ---------
cm_orig_test = confusion_matrix(y_true=y_test, y_pred=pred_original_test)
cm_best_test = confusion_matrix(y_true=y_test, y_pred=pred_best_test)

fig, (ax1, ax2) = plt.subplots(nrows=1,ncols=2, figsize=(15,5), sharey=False)
disp1 = ConfusionMatrixDisplay(confusion_matrix=cm_orig_test)
disp2 = ConfusionMatrixDisplay(confusion_matrix=cm_best_test)

disp1.plot(ax=ax1)
disp2.plot(ax=ax2)

ax1.set_title(" alpha = 1.0 (default)")
ax2.set_title(f"alpha = {best_alpha} (best)")

fig.suptitle("Final Ridge Prediction on TEST data")

plt.show()

# %%
from sklearn.metrics import f1_score

print("original alpha f1-score =", f1_score(y_true=y_test, y_pred=pred_original_test, average='macro'))
print("best alpha f1-score =", f1_score(y_true=y_test, y_pred=pred_best_test, average='macro'))
# Out:
# original alpha f1-score = 0.06564548635641636
# best alpha f1-score = 0.092074778212217

# %% [markdown]
# How can you decide if the difference between two classifiers is significant ?
#
# The cross-validated model seems to give the best results, however because it is difficult to conclude which model is better in the absence of large difference between both hyperparameters, we should try to make a statistical test on the repeated previous cross validations accuracy scores for each hyperaparameter, and compare their distribution using a t-test. The more fold/split are made for each hyperparameter, the higher the statistical power of the test (p-value).

# %%
# -- Your code here -- #


# 10 fold CV
cv = 20

# ---------- Perform CV for both alphas to generate multiple accuracy scores --------
# using default hyperparameter
clf_original = RidgeClassifier(alpha=1.0)
cv_scores_orig = cross_val_score(estimator=clf_original, X=X_train, y=y_train, cv=cv)


# using best hyperparameter alpha
clf_best = RidgeClassifier(alpha=best_alpha)
cv_scores_best = cross_val_score(estimator=clf_best, X=X_train, y=y_train, cv=cv)

print(cv_scores_orig)
print(cv_scores_best)
# Out:
# [0.05733333 0.07866667 0.08266667 0.064      0.06933333 0.09066667
#  0.05733333 0.068      0.06666667 0.05866667 0.06933333 0.08533333
#  0.06266667 0.06266667 0.08       0.06533333 0.06266667 0.07066667
#  0.06666667 0.076     ]
# [0.08266667 0.10266667 0.10666667 0.08933333 0.09733333 0.11466667
#  0.08266667 0.092      0.104      0.096      0.10266667 0.1
#  0.08533333 0.084      0.08533333 0.104      0.1        0.10666667
#  0.07733333 0.096     ]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,5), sharex=True, sharey=True)
ax1.boxplot(cv_scores_orig)
ax2.boxplot(cv_scores_best)

# Add points to boxplots
for i in cv_scores_orig:
    x = np.random.normal(1, 0.03) # Add some random "jitter" to the x-axis
    ax1.plot(x, i, 'r.', alpha=0.2)

for i in cv_scores_best:
    x = np.random.normal(1, 0.03) # Add some random "jitter" to the x-axis
    ax2.plot(x, i, 'r.', alpha=0.2)

ax1.set_title("alpha=1.0")
ax2.set_title(f"alpha={best_alpha}")

fig.suptitle(f"Comparison of CV scores distribution (k={cv}) for different Ridge alphas")
plt.show()

# %%
import scipy.stats as sp 

results = sp.ttest_rel(cv_scores_orig, cv_scores_best)

print("======== T-Test between CV accuracy score distributions ===========")
print(f"t-test result = {results.statistic}")
print(f"p-value = {results.pvalue}")
# Out:
# ======== T-Test between CV accuracy score distributions ===========
# t-test result = -12.623905152943586
# p-value = 1.0955683155703906e-10

# %% [markdown]
# We can confidently reject the null hypothesis that there is no statistical difference between the two groups. And thus we can conclude that increasing alpha by 1000 times has a statistically significant impact on the ridge classification accuracy on this dataset.
